# %% [markdown]
# # 01 — Streaming Dataset Exploration
#
# ## Purpose
#
# This notebook performs an initial exploration of the Movies and TV Shows on Streaming Platforms datasets.
#
# The goals are to:
#
# - Review the dataset structure and dimensions
# - Examine column names and data types
# - Identify missing values and duplicate records
# - Understand the main variables available for later analysis
# - Prepare for the data-cleaning stage

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

DATA_DIR = Path.cwd().parents[0] / "data"  # adjust if needed
# Example: df = pd.read_csv(DATA_DIR / "svod_sample.csv")
print("Place your dataset (e.g., svod_sample.csv) in the data/ folder.")
# Out:
# Place your dataset (e.g., svod_sample.csv) in the data/ folder.

# %%
# Example EDA once data is loaded
# df.head()
# df.info()
# df.describe(numeric_only=True)

# %% [markdown]
# ## Quick Plot Example

# %%
# if 'watch_time' in df.columns:
#     df['watch_time'].hist()
#     plt.title('Watch Time Distribution')
#     plt.show()
